# %% [markdown]
# # MLflow Training Tutorial
#
# This `train.pynb` Jupyter notebook predicts the quality of wine using [sklearn.linear_model.ElasticNet](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNet.html).
#
# > This is the Jupyter notebook version of the `train.py` example
#
# Attribution
# * The data set used in this example is from http://archive.ics.uci.edu/ml/datasets/Wine+Quality
# * P. Cortez, A. Cerdeira, F. Almeida, T. Matos and J. Reis.
# * Modeling wine preferences by data mining from physicochemical properties. In Decision Support Systems, Elsevier, 47(4):547-553, 2009.

# %%
# Wine Quality Sample
def train(in_alpha, in_l1_ratio):
    import os
    import warnings
    import sys

    import pandas as pd
    import numpy as np
    from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
    from sklearn.model_selection import train_test_split
    from sklearn.linear_model import ElasticNet

    import mlflow
    import mlflow.sklearn
    
    import logging
    logging.basicConfig(level=logging.WARN)
    logger = logging.getLogger(__name__)

    def eval_metrics(actual, pred):
        rmse = np.sqrt(mean_squared_error(actual, pred))
        mae = mean_absolute_error(actual, pred)
        r2 = r2_score(actual, pred)
        return rmse, mae, r2


    warnings.filterwarnings("ignore")
    np.random.seed(40)

    # Read the wine-quality csv file from the URL
    csv_url =\
        'http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
    try:
        data = pd.read_csv(csv_url, sep=';')
    except Exception as e:
        logger.exception(
            "Unable to download training & test CSV, check your internet connection. Error: %s", e)

    # Split the data into training and test sets. (0.75, 0.25) split.
    train, test = train_test_split(data)

    # The predicted column is "quality" which is a scalar from [3, 9]
    train_x = train.drop(["quality"], axis=1)
    test_x = test.drop(["quality"], axis=1)
    train_y = train[["quality"]]
    test_y = test[["quality"]]

    # Set default values if no alpha is provided
    if float(in_alpha) is None:
        alpha = 0.5
    else:
        alpha = float(in_alpha)

    # Set default values if no l1_ratio is provided
    if float(in_l1_ratio) is None:
        l1_ratio = 0.5
    else:
        l1_ratio = float(in_l1_ratio)

    # Useful for multiple runs (only doing one run in this sample notebook)    
    with mlflow.start_run():
        # Execute ElasticNet
        lr = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, random_state=42)
        lr.fit(train_x, train_y)

        # Evaluate Metrics
        predicted_qualities = lr.predict(test_x)
        (rmse, mae, r2) = eval_metrics(test_y, predicted_qualities)

        # Print out metrics
        print("Elasticnet model (alpha=%f, l1_ratio=%f):" % (alpha, l1_ratio))
        print("  RMSE: %s" % rmse)
        print("  MAE: %s" % mae)
        print("  R2: %s" % r2)

        # Log parameter, metrics, and model to MLflow
        mlflow.log_param("alpha", alpha)
        mlflow.log_param("l1_ratio", l1_ratio)
        mlflow.log_metric("rmse", rmse)
        mlflow.log_metric("r2", r2)
        mlflow.log_metric("mae", mae)

        mlflow.sklearn.log_model(lr, "model")

# %%
train(0.5, 0.5)
# Out:
# Elasticnet model (alpha=0.500000, l1_ratio=0.500000):
#   RMSE: 0.82224284975954
#   MAE: 0.6278761410160691
#   R2: 0.12678721972772689

# %%
train(0.2, 0.2)
# Out:
# Elasticnet model (alpha=0.200000, l1_ratio=0.200000):
#   RMSE: 0.7859129997062342
#   MAE: 0.6155290394093894
#   R2: 0.20224631822892092

# %%
train(0.1, 0.1)
# Out:
# Elasticnet model (alpha=0.100000, l1_ratio=0.100000):
#   RMSE: 0.7792546522251949
#   MAE: 0.6112547988118587
#   R2: 0.2157063843066196

# %%
# %env MLFLOW_TRACKING_URI=http://localhost:5050
# !mlflow run . -P alpha=0.5
# Out:
# env: MLFLOW_TRACKING_URI=http://localhost:5050
# 2020/06/08 09:11:08 INFO mlflow.projects: === Creating conda environment mlflow-d478fec63b86235a275910b6eba8ea2d575dbc26 ===
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# Downloading and Extracting Packages
# pip-20.0.2           | 1.7 MB    | ##################################### | 100%
# openssl-1.1.1g       | 2.5 MB    | ##################################### | 100%
# libffi-3.3           | 50 KB     | ##################################### | 100%
# mkl_random-1.0.1     | 324 KB    | ##################################### | 100%
# setuptools-47.1.1    | 514 KB    | ##################################### | 100%
# sqlite-3.31.1        | 1.1 MB    | ##################################### | 100%
# numpy-1.15.4         | 34 KB     | ##################################### | 100%
# mkl-2018.0.3         | 126.9 MB  | ##################################### | 100%
# ncurses-6.2          | 817 KB    | ##################################### | 100%
# xz-5.2.5             | 341 KB    | ##################################### | 100%
# readline-8.0         | 356 KB    | ##################################### | 100%
# numpy-base-1.15.4    | 3.4 MB    | ##################################### | 100%
# intel-openmp-2019.4  | 729 KB    | ##################################### | 100%
# tbb4py-2020.0        | 209 KB    | ##################################### | 100%
# mkl_fft-1.0.6        | 135 KB    | ##################################### | 100%
# scipy-1.1.0          | 13.2 MB   | ##################################### | 100%
# scikit-learn-0.19.1  | 3.9 MB    | ##################################### | 100%
# python-3.6.10        | 29.7 MB   | ##################################### | 100%
# certifi-2020.4.5.1   | 155 KB    | ##################################### | 100%
# wheel-0.34.2         | 51 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Ran pip subprocess with arguments:
# ['/home/niraj/.conda/envs/mlflow-d478fec63b86235a275910b6eba8ea2d575dbc26/bin/python', '-m', 'pip', 'install', '-U', '-r', '/home/niraj/mlflows/sklearn_elasticnet_wine/condaenv.mwoo0cxr.requirements.txt']
# Pip subprocess output:
# Collecting mlflow>=1.0
#   Downloading mlflow-1.8.0-py3-none-any.whl (10.4 MB)
# Collecting databricks-cli>=0.8.7
#   Downloading databricks-cli-0.11.0.tar.gz (49 kB)
# Collecting simplejson
#   Downloading simplejson-3.17.0.tar.gz (83 kB)
# Collecting sqlalchemy<=1.3.13
#   Downloading SQLAlchemy-1.3.13.tar.gz (6.0 MB)
# Collecting entrypoints
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting six>=1.10.0
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting gitpython>=2.1.0
#   Downloading GitPython-3.1.3-py3-none-any.whl (451 kB)
# Collecting gorilla
#   Downloading gorilla-0.3.0-py2.py3-none-any.whl (11 kB)
# Collecting pyyaml
#   Downloading PyYAML-5.3.1.tar.gz (269 kB)
# Collecting docker>=4.0.0
#   Downloading docker-4.2.1-py2.py3-none-any.whl (143 kB)
# Collecting cloudpickle
#   Downloading cloudpickle-1.4.1-py3-none-any.whl (26 kB)
# Collecting pandas
#   Downloading pandas-1.0.4-cp36-cp36m-manylinux1_x86_64.whl (10.1 MB)
# Collecting click>=7.0
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Requirement already satisfied, skipping upgrade: numpy in /home/niraj/.conda/envs/mlflow-d478fec63b86235a275910b6eba8ea2d575dbc26/lib/python3.6/site-packages (from mlflow>=1.0->-r /home/niraj/mlflows/sklearn_elasticnet_wine/condaenv.mwoo0cxr.requirements.txt (line 1)) (1.15.4)
# Collecting sqlparse
#   Downloading sqlparse-0.3.1-py2.py3-none-any.whl (40 kB)
# Collecting python-dateutil
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting alembic
#   Downloading alembic-1.4.2.tar.gz (1.1 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting requests>=2.17.3
#   Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
# Collecting querystring-parser
#   Downloading querystring_parser-1.2.4.tar.gz (5.5 kB)
# Collecting prometheus-flask-exporter
#   Downloading prometheus_flask_exporter-0.13.0.tar.gz (18 kB)
# Collecting gunicorn; platform_system != "Windows"
#   Downloading gunicorn-20.0.4-py2.py3-none-any.whl (77 kB)
# Collecting protobuf>=3.6.0
#   Downloading protobuf-3.12.2-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting Flask
#   Downloading Flask-1.1.2-py2.py3-none-any.whl (94 kB)
# Collecting tabulate>=0.7.7
#   Downloading tabulate-0.8.7-py3-none-any.whl (24 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.5-py3-none-any.whl (63 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting pytz>=2017.2
#   Downloading pytz-2020.1-py2.py3-none-any.whl (510 kB)
# Collecting Mako
#   Downloading Mako-1.1.3-py2.py3-none-any.whl (75 kB)
# Collecting python-editor>=0.3
#   Downloading python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.9-py2.py3-none-any.whl (126 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/niraj/.conda/envs/mlflow-d478fec63b86235a275910b6eba8ea2d575dbc26/lib/python3.6/site-packages (from requests>=2.17.3->mlflow>=1.0->-r /home/niraj/mlflows/sklearn_elasticnet_wine/condaenv.mwoo0cxr.requirements.txt (line 1)) (2020.4.5.1)
# Collecting idna<3,>=2.5
#   Downloading idna-2.9-py2.py3-none-any.whl (58 kB)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting prometheus_client
#   Downloading prometheus_client-0.8.0-py2.py3-none-any.whl (53 kB)
# Requirement already satisfied, skipping upgrade: setuptools>=3.0 in /home/niraj/.conda/envs/mlflow-d478fec63b86235a275910b6eba8ea2d575dbc26/lib/python3.6/site-packages (from gunicorn; platform_system != "Windows"->mlflow>=1.0->-r /home/niraj/mlflows/sklearn_elasticnet_wine/condaenv.mwoo0cxr.requirements.txt (line 1)) (47.1.1.post20200604)
# Collecting Werkzeug>=0.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting Jinja2>=2.10.1
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting smmap<4,>=3.0.1
#   Downloading smmap-3.0.4-py2.py3-none-any.whl (25 kB)
# Collecting MarkupSafe>=0.9.2
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Building wheels for collected packages: databricks-cli, simplejson, sqlalchemy, pyyaml, alembic, querystring-parser, prometheus-flask-exporter
#   Building wheel for databricks-cli (setup.py): started
#   Building wheel for databricks-cli (setup.py): finished with status 'done'
#   Created wheel for databricks-cli: filename=databricks_cli-0.11.0-py3-none-any.whl size=90300 sha256=00fba55dfe0e17cde119319ad6cfdacc6a6d1292d9eef99bc4f5ec250e9c276b
#   Stored in directory: /home/niraj/.cache/pip/wheels/42/9f/68/f17e7b4af8b8b954ce3a590ac1ad3a4eccd756a13348db31d6
#   Building wheel for simplejson (setup.py): started
#   Building wheel for simplejson (setup.py): finished with status 'done'
#   Created wheel for simplejson: filename=simplejson-3.17.0-py3-none-any.whl size=55462 sha256=0c96077341ebb8d3200a6fd92a85cf1e22f7d2d33a578b11d5a89f89422dfba1
#   Stored in directory: /home/niraj/.cache/pip/wheels/c2/95/a2/477b46cfe980061fddc4cb76ed4657eceec35d2b2090355e41
#   Building wheel for sqlalchemy (setup.py): started
#   Building wheel for sqlalchemy (setup.py): finished with status 'done'
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.13-cp36-cp36m-linux_x86_64.whl size=1171666 sha256=541864334b084ed2cb49e5427e88f3c9516ca2fabc1347dff3d8ea628339aa81
#   Stored in directory: /home/niraj/.cache/pip/wheels/28/3e/f9/8eca04781258bb6956ffba37e4e6e6951e5b3a16d4494b91cb
#   Building wheel for pyyaml (setup.py): started
#   Building wheel for pyyaml (setup.py): finished with status 'done'
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44621 sha256=8985e3d9b38712852418c199838645564f2ac06e335aecd8753c8afb38bd15e7
#   Stored in directory: /home/niraj/.cache/pip/wheels/e5/9d/ad/2ee53cf262cba1ffd8afe1487eef788ea3f260b7e6232a80fc
#   Building wheel for alembic (PEP 517): started
#   Building wheel for alembic (PEP 517): finished with status 'done'
#   Created wheel for alembic: filename=alembic-1.4.2-py2.py3-none-any.whl size=159543 sha256=4d95105f0bcfde6803a0dade922c3bfc53553e26603715d98e7ee722a31779a0
#   Stored in directory: /home/niraj/.cache/pip/wheels/f2/50/61/5cc491b0ca39be60dfb4dce940b389ff91b847d62e0eb2d680
#   Building wheel for querystring-parser (setup.py): started
#   Building wheel for querystring-parser (setup.py): finished with status 'done'
#   Created wheel for querystring-parser: filename=querystring_parser-1.2.4-py3-none-any.whl size=7076 sha256=96c58d579177a1ac3339624c7fcc9a7a06f1fd5b2ec85a07d7c14375e80b1b6f
#   Stored in directory: /home/niraj/.cache/pip/wheels/87/da/0d/a9e8051c7c19128c271107462cd444b37afc22aaed15061ed5
#   Building wheel for prometheus-flask-exporter (setup.py): started
#   Building wheel for prometheus-flask-exporter (setup.py): finished with status 'done'
#   Created wheel for prometheus-flask-exporter: filename=prometheus_flask_exporter-0.13.0-py3-none-any.whl size=14944 sha256=5cac10a4d655a00da4360f3fd926c4a623ec465dd3bd63dbcbb651f79a7e712c
#   Stored in directory: /home/niraj/.cache/pip/wheels/0e/fb/b5/7cf166931a7386f3e0ddb6f7cd1d763d95b4a29823657ef429
# Successfully built databricks-cli simplejson sqlalchemy pyyaml alembic querystring-parser prometheus-flask-exporter
# Installing collected packages: click, urllib3, idna, chardet, requests, tabulate, six, databricks-cli, simplejson, sqlalchemy, entrypoints, smmap, gitdb, gitpython, gorilla, pyyaml, websocket-client, docker, cloudpickle, pytz, python-dateutil, pandas, sqlparse, MarkupSafe, Mako, python-editor, alembic, querystring-parser, prometheus-client, Werkzeug, Jinja2, itsdangerous, Flask, prometheus-flask-exporter, gunicorn, protobuf, mlflow
# Successfully installed Flask-1.1.2 Jinja2-2.11.2 Mako-1.1.3 MarkupSafe-1.1.1 Werkzeug-1.0.1 alembic-1.4.2 chardet-3.0.4 click-7.1.2 cloudpickle-1.4.1 databricks-cli-0.11.0 docker-4.2.1 entrypoints-0.3 gitdb-4.0.5 gitpython-3.1.3 gorilla-0.3.0 gunicorn-20.0.4 idna-2.9 itsdangerous-1.1.0 mlflow-1.8.0 pandas-1.0.4 prometheus-client-0.8.0 prometheus-flask-exporter-0.13.0 protobuf-3.12.2 python-dateutil-2.8.1 python-editor-1.0.4 pytz-2020.1 pyyaml-5.3.1 querystring-parser-1.2.4 requests-2.23.0 simplejson-3.17.0 six-1.15.0 smmap-3.0.4 sqlalchemy-1.3.13 sqlparse-0.3.1 tabulate-0.8.7 urllib3-1.25.9 websocket-client-0.57.0
#
# #
# # To activate this environment, use
# #
# #     $ conda activate mlflow-d478fec63b86235a275910b6eba8ea2d575dbc26
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# 2020/06/08 09:12:42 INFO mlflow.projects: === Created directory /tmp/tmpxttsrs97 for downloading remote URIs passed to arguments of type 'path' ===
# 2020/06/08 09:12:42 INFO mlflow.projects: === Running command 'source activate mlflow-d478fec63b86235a275910b6eba8ea2d575dbc26 1>&2 && python train.py 0.5 0.1' in run with ID 'cc57e9d5aef246a381375f8e2b2aeb68' ===
# Elasticnet model (alpha=0.500000, l1_ratio=0.100000):
#   RMSE: 0.7460550348172179
#   MAE: 0.576381895873763
#   R2: 0.21136606570632266
# Traceback (most recent call last):
#   File "train.py", line 84, in <module>
#     mlflow.sklearn.log_model(lr, "model", registered_model_name="ElasticnetWineModel")
#   File "/home/niraj/.conda/envs/mlflow-d478fec63b86235a275910b6eba8ea2d575dbc26/lib/python3.6/site-packages/mlflow/sklearn.py", line 211, in log_model
#     registered_model_name=registered_model_name)
#   File "/home/niraj/.conda/envs/mlflow-d478fec63b86235a275910b6eba8ea2d575dbc26/lib/python3.6/site-packages/mlflow/models/__init__.py", line 102, in log
#     mlflow.tracking.fluent.log_artifacts(local_path, artifact_path)
#   File "/home/niraj/.conda/envs/mlflow-d478fec63b86235a275910b6eba8ea2d575dbc26/lib/python3.6/site-packages/mlflow/tracking/fluent.py", line 323, in log_artifacts
#     MlflowClient().log_artifacts(run_id, local_dir, artifact_path)
#   File "/home/niraj/.conda/envs/mlflow-d478fec63b86235a275910b6eba8ea2d575dbc26/lib/python3.6/site-packages/mlflow/tracking/client.py", line 267, in log_artifacts
#     self._tracking_client.log_artifacts(run_id, local_dir, artifact_path)
#   File "/home/niraj/.conda/envs/mlflow-d478fec63b86235a275910b6eba8ea2d575dbc26/lib/python3.6/site-packages/mlflow/tracking/_tracking_service/client.py", line 268, in log_artifacts
#     artifact_repo.log_artifacts(local_dir, artifact_path)
#   File "/home/niraj/.conda/envs/mlflow-d478fec63b86235a275910b6eba8ea2d575dbc26/lib/python3.6/site-packages/mlflow/store/artifact/local_artifact_repo.py", line 50, in log_artifacts
#     mkdir(artifact_dir)
#   File "/home/niraj/.conda/envs/mlflow-d478fec63b86235a275910b6eba8ea2d575dbc26/lib/python3.6/site-packages/mlflow/utils/file_utils.py", line 110, in mkdir
#     raise e
#   File "/home/niraj/.conda/envs/mlflow-d478fec63b86235a275910b6eba8ea2d575dbc26/lib/python3.6/site-packages/mlflow/utils/file_utils.py", line 107, in mkdir
#     os.makedirs(target)
#   File "/home/niraj/.conda/envs/mlflow-d478fec63b86235a275910b6eba8ea2d575dbc26/lib/python3.6/os.py", line 210, in makedirs
#     makedirs(head, mode, exist_ok)
#   File "/home/niraj/.conda/envs/mlflow-d478fec63b86235a275910b6eba8ea2d575dbc26/lib/python3.6/os.py", line 210, in makedirs
#     makedirs(head, mode, exist_ok)
#   File "/home/niraj/.conda/envs/mlflow-d478fec63b86235a275910b6eba8ea2d575dbc26/lib/python3.6/os.py", line 210, in makedirs
#     makedirs(head, mode, exist_ok)
#   File "/home/niraj/.conda/envs/mlflow-d478fec63b86235a275910b6eba8ea2d575dbc26/lib/python3.6/os.py", line 220, in makedirs
#     mkdir(name, mode)
# PermissionError: [Errno 13] Permission denied: '/opt/mlflow-demo_sq/mlruns/0'
# 2020/06/08 09:12:45 ERROR mlflow.cli: === Run (ID 'cc57e9d5aef246a381375f8e2b2aeb68') failed ===

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/anaconda3/lib/python3.7/site-packages (from pandas) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/anaconda3/lib/python3.7/site-packages (from pandas) (2.6.1)
# Requirement already satisfied: numpy>=1.13.3 in /opt/anaconda3/lib/python3.7/site-packages (from pandas) (1.18.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)
